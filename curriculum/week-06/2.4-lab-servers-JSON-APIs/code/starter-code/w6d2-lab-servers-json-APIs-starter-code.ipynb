# %% [markdown]
# # APIs Lab
# In this lab we will practice using APIs to retrieve and store data.

# %%
# Imports at the top
import json
import urllib
import pandas as pd
import numpy as np
import requests
import json
import re
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Exercise 1: Get Data From Sheetsu
#
# [Sheetsu](https://sheetsu.com/) is an online service that allows you to access any Google spreadsheet from an API. This can be a very handy way to share a dataset with colleagues as well as to create a mini centralized data storage, that is simpler to edit than a database.
#
# A Google Spreadsheet with wine data can be found [here](https://docs.google.com/a/generalassemb.ly/spreadsheets/d/1JWRwDnwIMLgvPqNMdJLmAJgzvz0K3zAUc6jev3ci1c8/edit?usp=sharing).
#
# You can access it through the Sheetsu API at this endpoint: https://sheetsu.com/apis/v1.0/cc9420722ae4. [Here](https://sheetsu.com/docs/beta) is Sheetsu's documentation.
#
#
# Questions:
#
# 1. Use the requests library to access the document. Inspect the response text. What kind of data is it?
# 2. Check the status code of the response object. What code is it?
# 3. Use the appropriate libraries and read functions to read the response into a Pandas Dataframe
# 4. Once you've imported the data into a dataframe, check the value of the 5th line: what's the price?

# %%
api_base_url = 'https://sheetsu.com/apis/v1.0/cc9420722ae4'

# %%
api_response = requests.get(api_base_url)
api_response.text[:200]
# Out:
# u'[{"Color":"W","Region":"Portugal","Country":"Portugal","Vintage":"2013","Vinyard":"Vinho Verde","Name":"","Grape":"","Consumed In":"2015","Score":"4","Price":""},{"Color":"W","Region":"France","Countr'

# %%
response = json.loads(api_response.text)

# %%
response
# Out:
# [{u'Color': u'W',
#   u'Consumed In': u'2015',
#   u'Country': u'Portugal',
#   u'Grape': u'',
#   u'Name': u'',
#   u'Price': u'',
#   u'Region': u'Portugal',
#   u'Score': u'4',
#   u'Vintage': u'2013',
#   u'Vinyard': u'Vinho Verde'},
#  {u'Color': u'W',
#   u'Consumed In': u'2015',
#   u'Country': u'France',
#   u'Grape': u'',
#   u'Name': u'',
#   u'Price': u'17.8',
#   u'Region': u'France',
#   u'Score': u'3',
#   u'Vintage': u'2013',
#   u'Vinyard': u'Peyruchet'},
#  {u'Color': u'W',
#   u'Consumed In': u'2015',
#   u'Country': u'Oregon',
#   u'Grape': u'',
#   u'Name': u'',
#   u'Price': u'20',
#   u'Region': u'Oregon',
#   u'Score': u'3',
#   u'Vintage': u'2013',
#   u'Vinyard': u'Abacela'},
#  {u'Color': u'W',
#   u'Consumed In': u'2015',
#   u'Country': u'Spain',
#   u'Grape': u'chardonay',
#   u'Name': u'',
#   u'Price': u'7',
#   u'Region': u'Spain',
#   u'Score': u'2.5',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Ochoa'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'chiraz, cab',
#   u'Name': u'Spice Trader',
#   u'Price': u'6',
#   u'Region': u'',
#   u'Score': u'3',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Heartland'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'cab',
#   u'Name': u'',
#   u'Price': u'13',
#   u'Region': u'California',
#   u'Score': u'3.5',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Crow Canyon'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'#14',
#   u'Price': u'21',
#   u'Region': u'Oregon',
#   u'Score': u'2.5',
#   u'Vintage': u'2013',
#   u'Vinyard': u'Abacela'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'France',
#   u'Grape': u'merlot, cab',
#   u'Name': u'',
#   u'Price': u'12',
#   u'Region': u'Bordeaux',
#   u'Score': u'3.5',
#   u'Vintage': u'2012',
#   u'Vinyard': u'David Beaulieu'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'France',
#   u'Grape': u'merlot, cab',
#   u'Name': u'',
#   u'Price': u'11.99',
#   u'Region': u'Medoc',
#   u'Score': u'3.5',
#   u'Vintage': u'2011',
#   u'Vinyard': u'Chantemerle'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'merlot',
#   u'Name': u'',
#   u'Price': u'13',
#   u'Region': u'Washington',
#   u'Score': u'4',
#   u'Vintage': u'2011',
#   u'Vinyard': u'Hyatt'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'Italy',
#   u'Grape': u'sangiovese',
#   u'Name': u'Rosso Dei Poggi',
#   u'Price': u'12',
#   u'Region': u'Tuscany',
#   u'Score': u'3',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Rosso Dei Poggi'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'',
#   u'Grape': u'',
#   u'Name': u"Montepulciano D'Abruzzo",
#   u'Price': u'22',
#   u'Region': u'Tuscany',
#   u'Score': u'4.5',
#   u'Vintage': u'2013',
#   u'Vinyard': u'Orizzonti'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'chiraz',
#   u'Name': u'',
#   u'Price': u'7',
#   u'Region': u'Oregon',
#   u'Score': u'3.5',
#   u'Vintage': u'2010',
#   u'Vinyard': u'Abacelo'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'Italy',
#   u'Grape': u'sangiovese',
#   u'Name': u'Rosso Di Montalcino',
#   u'Price': u'15',
#   u'Region': u'Tuscany',
#   u'Score': u'3.5',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Ridolfi'},
#  {u'Color': u'W',
#   u'Consumed In': u'2013',
#   u'Country': u'France',
#   u'Grape': u'sauvignon blanc',
#   u'Name': u'Sancerre Cuvee Des Moulins Bales',
#   u'Price': u'12',
#   u'Region': u'Loire',
#   u'Score': u'3',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Celestin Blobdeau'},
#  {u'Color': u'R',
#   u'Consumed In': u'2013',
#   u'Country': u'US',
#   u'Grape': u'pinot noir',
#   u'Name': u'Meiomi',
#   u'Price': u'13',
#   u'Region': u'Napa',
#   u'Score': u'3',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Belle Glos'},
#  {u'Color': u'R',
#   u'Consumed In': u'2013',
#   u'Country': u'France',
#   u'Grape': u'',
#   u'Name': u'Saint Drezery Prestige',
#   u'Price': u'13',
#   u'Region': u'France',
#   u'Score': u'3',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Puech-Haut'},
#  {u'Color': u'R',
#   u'Consumed In': u'2013',
#   u'Country': u'France',
#   u'Grape': u'',
#   u'Name': u'Saint Drezery Prestige',
#   u'Price': u'14',
#   u'Region': u'France',
#   u'Score': u'2',
#   u'Vintage': u'2011',
#   u'Vinyard': u'Puech-Haut'},
#  {u'Color': u'W',
#   u'Consumed In': u'2014',
#   u'Country': u'US',
#   u'Grape': u'sauvignon blanc',
#   u'Name': u'Sauvignon Blanc',
#   u'Price': u'14.5',
#   u'Region': u'Nappa',
#   u'Score': u'4',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Honig'},
#  {u'Color': u'W',
#   u'Consumed In': u'2014',
#   u'Country': u'US',
#   u'Grape': u'sauvignon blanc',
#   u'Name': u'Uppercut North Coast',
#   u'Price': u'11',
#   u'Region': u'Nappa',
#   u'Score': u'3',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Provenance'},
#  {u'Color': u'R',
#   u'Consumed In': u'2014',
#   u'Country': u'Italy',
#   u'Grape': u'',
#   u'Name': u"Nero d'Avola",
#   u'Price': u'',
#   u'Region': u'Sicily',
#   u'Score': u'',
#   u'Vintage': u'2011',
#   u'Vinyard': u'Baglio Di Pianetto'},
#  {u'Color': u'P',
#   u'Consumed In': u'2014',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Cape Blush',
#   u'Price': u'10',
#   u'Region': u'Truro',
#   u'Score': u'4',
#   u'Vintage': u'2013',
#   u'Vinyard': u'Truro Vineyards'},
#  {u'Color': u'W',
#   u'Consumed In': u'2014',
#   u'Country': u'US',
#   u'Grape': u'pinot griogio',
#   u'Name': u'Pinot Grigio',
#   u'Price': u'10',
#   u'Region': u'Truro',
#   u'Score': u'3',
#   u'Vintage': u'2013',
#   u'Vinyard': u'Truro Vineyards'},
#  {u'Color': u'R',
#   u'Consumed In': u'2014',
#   u'Country': u'France',
#   u'Grape': u'',
#   u'Name': u'Cru Classe',
#   u'Price': u'',
#   u'Region': u'Provence',
#   u'Score': u'3.5',
#   u'Vintage': u'2013',
#   u'Vinyard': u'Chateau de la Clapiere'},
#  {u'Color': u'W',
#   u'Consumed In': u'2015',
#   u'Country': u'France',
#   u'Grape': u'cabernet sauvignon',
#   u'Name': u'Domaine du Claouset',
#   u'Price': u'',
#   u'Region': u'Bordeaux',
#   u'Score': u'3',
#   u'Vintage': u'2013',
#   u'Vinyard': u'Domaine du Claouset'},
#  {u'Color': u'W',
#   u'Consumed In': u'2015',
#   u'Country': u'',
#   u'Grape': u'sauvignon blanc',
#   u'Name': u'Sauvignon Blanc',
#   u'Price': u'',
#   u'Region': u'Napa',
#   u'Score': u'3.5',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Two Angels'},
#  {u'Color': u'W',
#   u'Consumed In': u'2015',
#   u'Country': u'Portugal',
#   u'Grape': u'',
#   u'Name': u'Vinho Verde',
#   u'Price': u'',
#   u'Region': u'Portugal',
#   u'Score': u'3.5',
#   u'Vintage': u'2013',
#   u'Vinyard': u'Mapreco'},
#  {u'Color': u'W',
#   u'Consumed In': u'2015',
#   u'Country': u'France',
#   u'Grape': u'Chablis, Vincent Dampt, Vaillons 1er (Burgundy, France) 2012 W/ Limestone taste',
#   u'Name': u'Vincent Dampt',
#   u'Price': u'35',
#   u'Region': u'Burgundy',
#   u'Score': u'4',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Vaillons'},
#  {u'Color': u'W',
#   u'Consumed In': u'2015',
#   u'Country': u'Spain',
#   u'Grape': u'Albarino, Granbazan (Rias Baixas) 2012',
#   u'Name': u'Albarino',
#   u'Price': u'15',
#   u'Region': u'Rias Baixas',
#   u'Score': u'4',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Granbazan'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'My wonderful wine',
#   u'Price': u'200',
#   u'Region': u'Sonoma',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''}]

# %%
type(response)
# Out:
# list

# %%
response[0]
# Out:
# {u'Color': u'W',
#  u'Consumed In': u'2015',
#  u'Country': u'Portugal',
#  u'Grape': u'',
#  u'Name': u'',
#  u'Price': u'',
#  u'Region': u'Portugal',
#  u'Score': u'4',
#  u'Vintage': u'2013',
#  u'Vinyard': u'Vinho Verde'}

# %%
api_response.status_code
# Out:
# 200

# %%
wd = pd.DataFrame(response)
print wd.head(3)
# Out:
#   Color Consumed In   Country Grape Name Price    Region Score Vintage  \
# 0     W        2015  Portugal                   Portugal     4    2013
# 1     W        2015    France             17.8    France     3    2013
# 2     W        2015    Oregon               20    Oregon     3    2013
#
#        Vinyard
# 0  Vinho Verde
# 1    Peyruchet
# 2      Abacela

# %%
wd = pd.read_json(api_response.text)
wd.tail(2)
# Out:
#    Color  Consumed In Country Grape               Name Price  Region Score  \
# 59     R         2015      US        My wonderful wine   200  Sonoma    10
# 60     R         2015      US        My wonderful wine   200  Sonoma    10
#
#     Vintage Vinyard
# 59     1973
# 60     1973

# %%
wd[wd['Color']=='R'][['Vinyard', 'Grape', 'Name']]
# Out:
#                    Vinyard        Grape                     Name
# 4                Heartland  chiraz, cab             Spice Trader
# 5              Crow Canyon          cab
# 6                  Abacela                                   #14
# 7           David Beaulieu  merlot, cab
# 8              Chantemerle  merlot, cab
# 9                    Hyatt       merlot
# 10         Rosso Dei Poggi   sangiovese          Rosso Dei Poggi
# 11               Orizzonti               Montepulciano D'Abruzzo
# 12                 Abacelo       chiraz
# 13                 Ridolfi   sangiovese      Rosso Di Montalcino
# 15              Belle Glos   pinot noir                   Meiomi
# 16              Puech-Haut                Saint Drezery Prestige
# 17              Puech-Haut                Saint Drezery Prestige
# 20      Baglio Di Pianetto                          Nero d'Avola
# 23  Chateau de la Clapiere                            Cru Classe
# 29                                             My wonderful wine
# 30                                             My wonderful wine
# 31                                             My wonderful wine
# 32                                             My wonderful wine
# 33                                             My wonderful wine
# 34                                             My wonderful wine
# 35                                             My wonderful wine
# 36                                             My wonderful wine
# 37                                             My wonderful wine
# 38                                             My wonderful wine
# 39                                             My wonderful wine
# 40                                             My wonderful wine
# 41                                             My wonderful wine
# 42                                             My wonderful wine
# 43                                             My wonderful wine
# 44                                             My wonderful wine
# 45                                             My wonderful wine
# 46                                             My wonderful wine
# 47                                             My wonderful wine
# 48                                             My wonderful wine
# 49                                             My wonderful wine
# 50                                             My wonderful wine
# 51                                             My wonderful wine
# 52                                             My wonderful wine
# 53                                             My wonderful wine
# 54                                             My wonderful wine
# 55                                             My wonderful wine
# 56                                             My wonderful wine
# 57                                             My wonderful wine
# 58                                             My wonderful wine
# 59                                             My wonderful wine
# 60                                             My wonderful wine

# %%
wd['Vinyard'].dtype
# Out:
# dtype('O')

# %%
wd[wd['Color']=='Crow Canyon'][['Vinyard', 'Grape', 'Name']]

# %%
wd['Name'][5]
# Out:
# u''

# %%
wd = wd.replace('', np.nan)

# %%
print wd.head(3)
# Out:
#   Color  Consumed In   Country Grape Name Price    Region Score  Vintage  \
# 0     W         2015  Portugal   NaN  NaN   NaN  Portugal     4     2013
# 1     W         2015    France   NaN  NaN  17.8    France     3     2013
# 2     W         2015    Oregon   NaN  NaN    20    Oregon     3     2013
#
#        Vinyard
# 0  Vinho Verde
# 1    Peyruchet
# 2      Abacela

# %%
print wd.tail(3)
# Out:
#    Color  Consumed In Country Grape               Name Price  Region Score  \
# 58     R         2015      US   NaN  My wonderful wine   200  Sonoma    10
# 59     R         2015      US   NaN  My wonderful wine   200  Sonoma    10
# 60     R         2015      US   NaN  My wonderful wine   200  Sonoma    10
#
#     Vintage Vinyard
# 58     1973     NaN
# 59     1973     NaN
# 60     1973     NaN

# %%
wd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61 entries, 0 to 60
# Data columns (total 10 columns):
# Color          61 non-null object
# Consumed In    61 non-null int64
# Country        59 non-null object
# Grape          18 non-null object
# Name           52 non-null object
# Price          55 non-null object
# Region         60 non-null object
# Score          60 non-null object
# Vintage        61 non-null int64
# Vinyard        29 non-null object
# dtypes: int64(2), object(8)
# memory usage: 5.2+ KB

# %% [markdown]
# > Answers:
#     1. A JSON string.
#     2. 200
#     3. Options inlucde: pd.read_json; json.loads + pd.Dataframe
#     4. 5

# %% [markdown]
# ### Exercise 2: Post Data to Sheetsu
# Now that we've learned how to read data, it'd be great if we could also write data. For this we will need to use a _POST_ request.
#
# 1. Use the post command to add the following data to the spreadsheet:

# %%
post_data = {
'Grape' : ''
, 'Name' : 'My wonderful wine'
, 'Color' : 'R'
, 'Country' : 'US'
, 'Region' : 'Sonoma'
, 'Vinyard' : ''
, 'Score' : '10'
, 'Consumed In' : '2015'
, 'Vintage' : '1973'
, 'Price' : '200'
}

# %% [markdown]
# 1. What status did you get? How can you check that you actually added the data correctly?
# - In this exercise, your classmates are adding data to the same spreadsheet. What happens because of this? Is it a problem? How could you mitigate it?

# %% [markdown]
# ## Exercise 3: Data munging
#
# Get back to the dataframe you've created in the beginning. Let's do some data munging:
#
# 1. Search for missing data
#     - Is there any missing data? How do you deal with it?
#     - Is there any data you can just remove?
#     - Are the data types appropriate?
# - Summarize the data
#     - Try using describe, min, max, mean, var

# %% [markdown]
# ## Exercise 4: Feature Extraction
#
# We would like to use a regression tree to predict the score of a wine. In order to do that, we first need to select and engineer appropriate features.
#
# - Set the target to be the Score column, drop the rows with no score
# - Use pd.get_dummies to create dummy features for all the text columns
# - Fill the nan values in the numerical columns, using an appropriate method
# - Train a Decision tree regressor on the Score, using a train test split:
#         X_train, X_test, y_train, y_test, = train_test_split(X, y, test_size=0.3, random_state=42)
# - Plot the test values, the predicted values and the residuals
# - Calculate R^2 score
# - Discuss your findings

# %% [markdown]
# ## Exercise 5: IMDB Movies
#
# Sometimes an API doesn't provide all the information we would like to get and we need to be creative.
# Here we will use a combination of scraping and API calls to investigate the ratings and gross earnings of famous movies.

# %% [markdown]
# ## 5.a Get top movies
#
# The Internet Movie Database contains data about movies. Unfortunately it does not have a public API.
#
# The page http://www.imdb.com/chart/top contains the list of the top 250 movies of all times. Retrieve the page using the requests library and then parse the html to obtain a list of the `movie_ids` for these movies. You can parse it with regular expression or using a library like `BeautifulSoup`.
#
# **Hint:** movie_ids look like this: `tt2582802`

# %% [markdown]
# ## 5.b Get top movies data
#
# Although the Internet Movie Database does not have a public API, an open API exists at http://www.omdbapi.com.
#
# Use this API to retrieve information about each of the 250 movies you have extracted in the previous step.
# - Check the documentation of omdbapi.com to learn how to request movie data by id
# - Define a function that returns a python object with all the information for a given id
# - Iterate on all the IDs and store the results in a list of such objects
# - Create a Pandas Dataframe from the list

# %% [markdown]
# ## 5.c Get gross data
#
# The OMDB API is great, but it does not provide information about Gross Revenue of the movie. We'll revert back to scraping for this.
#
# - Write a function that retrieves the gross revenue from the entry page at imdb.com
# - The function should handle the exception of when the page doesn't report gross revenue
# - Retrieve the gross revenue for each movie and store it in a separate dataframe

# %% [markdown]
# ## 5.d Data munging
#
# - Now that you have movie information and gross revenue information, let's clean the two datasets.
# - Check if there are null values. Be careful they may appear to be valid strings.
# - Convert the columns to the appropriate formats. In particular handle:
#     - Released
#     - Runtime
#     - year
#     - imdbRating
#     - imdbVotes
# - Merge the data from the two datasets into a single one

# %% [markdown]
# ## 5.d Text vectorization
#
# There are several columns in the data that contain a comma separated list of items, for example the Genre column and the Actors column. Let's transform those to binary columns using the count vectorizer from scikit learn.
#
# Append these columns to the merged dataframe.
#
# **Hint:** In order to get the actors name right, you'll have to set the `token_pattern` parameter in `CountVectorizer` to u'(?u)\\w+\.?\\w?\.? \\w+'. Can you see why? How does this differ from the default?

# %% [markdown]
# ## Bonus:
#
# - What are the top 10 grossing movies?
# - Who are the 10 actors that appear in the most movies?
# - What's the average grossing of the movies in which each of these actors appear?
# - What genre is the oldest movie?
