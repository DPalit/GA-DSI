# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import linear_model
import seaborn as sns

df = pd.read_csv('/Users/Debjani/GA-DSI/curriculum/week-03/5.1-regression-challenge/datasets/challenge-dataset.csv')
print df
# Out:
#      world_rank                                    university_name  \
# 0             1                                 Harvard University
# 1             2                 California Institute of Technology
# 2             3              Massachusetts Institute of Technology
# 3             4                                Stanford University
# 4             5                               Princeton University
# 5             6                            University of Cambridge
# 6             6                               University of Oxford
# 7             8                 University of California, Berkeley
# 8             9                            Imperial College London
# 9            10                                    Yale University
# 10           11              University of California, Los Angeles
# 11           12                              University of Chicago
# 12           13                           Johns Hopkins University
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2603 entries, 0 to 2602
# Data columns (total 14 columns):
# world_rank                2603 non-null object
# university_name           2603 non-null object
# country                   2603 non-null object
# teaching                  2603 non-null float64
# international             2603 non-null object
# research                  2603 non-null float64
# citations                 2603 non-null float64
# income                    2603 non-null object
# total_score               1803 non-null object
# num_students              2544 non-null object
# student_staff_ratio       2544 non-null float64
# international_students    2536 non-null object
# female_male_ratio         2370 non-null object
# year                      2603 non-null int64
# dtypes: float64(4), int64(1), object(9)
# memory usage: 284.8+ KB

# %%
print df.head()
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching international  research  citations income total_score  \
# 0      99.7          72.4      98.7       98.8   34.5        96.1
# 1      97.7          54.6      98.0       99.9   83.7          96
# 2      97.8          82.3      91.4       99.9   87.5        95.6
# 3      98.3          29.5      98.1       99.2   64.3        94.3
# 4      90.9          70.3      95.4       99.9      -        94.2
#
#   num_students  student_staff_ratio international_students female_male_ratio  \
# ...

# %%
total_df = df[(df['total_score'].notnull()) & (df['total_score']!='-')]
print total_df
# Out:
#      world_rank                                    university_name  \
# 0             1                                 Harvard University
# 1             2                 California Institute of Technology
# 2             3              Massachusetts Institute of Technology
# 3             4                                Stanford University
# 4             5                               Princeton University
# 5             6                            University of Cambridge
# 6             6                               University of Oxford
# 7             8                 University of California, Berkeley
# 8             9                            Imperial College London
# 9            10                                    Yale University
# 10           11              University of California, Los Angeles
# 11           12                              University of Chicago
# 12           13                           Johns Hopkins University
# ...

# %%
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1001 entries, 0 to 1602
# Data columns (total 14 columns):
# world_rank                1001 non-null object
# university_name           1001 non-null object
# country                   1001 non-null object
# teaching                  1001 non-null float64
# international             1001 non-null float64
# research                  1001 non-null float64
# citations                 1001 non-null float64
# income                    1001 non-null float64
# total_score               1001 non-null float64
# num_students              984 non-null float64
# student_staff_ratio       984 non-null float64
# international_students    983 non-null float64
# female_male_ratio         1001 non-null object
# year                      1001 non-null int64
# dtypes: float64(9), int64(1), object(4)
# memory usage: 117.3+ KB

# %%
total_df['international'] = total_df['international'].apply(lambda x: str(x).replace('-','0')).apply(lambda x: float(x))
total_df
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#      world_rank                                    university_name  \
# 0             1                                 Harvard University
# 1             2                 California Institute of Technology
# 2             3              Massachusetts Institute of Technology
# 3             4                                Stanford University
# 4             5                               Princeton University
# 5             6                            University of Cambridge
# 6             6                               University of Oxford
# 7             8                 University of California, Berkeley
# ...

# %%
total_df['income'].unique()
# Out:
# array(['34.5', '83.7', '87.5', '64.3', '-', '57', '73.5', '92.9', '100',
#        '34.7', '59.6', '43.7', '53.7', '56.5', '39', '32.8', '95.1',
#        '89.8', '42.6', '50.2', '51.8', '40.5', '47.7', '98.6', '42.2',
#        '64.1', '30.7', '73.3', '31.7', '29.2', '38', '30.3', '84.2', '48',
#        '53.9', '67.1', '97.8', '29.6', '40.4', '37.9', '36.2', '90.8',
#        '52.7', '31.6', '44.1', '29.1', '57.1', '39.1', '33.9', '38.4',
#        '30.5', '33.2', '37.7', '43.8', '45.8', '26.1', '30.2', '32.6',
#        '44', '43', '26.7', '32.4', '60.5', '99.8', '35.7', '32.7', '97.7',
#        '43.4', '38.9', '95.5', '97.1', '28.8', '44.5', '61', '73.4',
#        '27.4', '82.3', '79.8', '41.5', '42.5', '40.3', '81.4', '26.4',
#        '49.3', '30', '55.3', '61.1', '34.8', '36', '39.5', '57.2', '47',
#        '99.4', '31.1', '60', '40', '49.6', '50.1', '37.5', '38.8', '40.6',
#        '61.5', '38.3', '34.2', '41.2', '41.6', '29.7', '27.8', '40.8',
# ...

# %%
total_df['income'] = total_df['income'].apply(lambda x: str(x).replace('-','0')).apply(lambda x: float(x))
total_df.head(3)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
#
#    teaching  international  research  citations  income total_score  \
# 0      99.7           72.4      98.7       98.8    34.5        96.1
# 1      97.7           54.6      98.0       99.9    83.7          96
# 2      97.8           82.3      91.4       99.9    87.5        95.6
#
# ...

# %%
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1001 entries, 0 to 1602
# Data columns (total 14 columns):
# world_rank                1001 non-null object
# university_name           1001 non-null object
# country                   1001 non-null object
# teaching                  1001 non-null float64
# international             1001 non-null float64
# research                  1001 non-null float64
# citations                 1001 non-null float64
# income                    1001 non-null float64
# total_score               1001 non-null object
# num_students              984 non-null object
# student_staff_ratio       984 non-null float64
# international_students    983 non-null object
# female_male_ratio         897 non-null object
# year                      1001 non-null int64
# dtypes: float64(6), int64(1), object(7)
# memory usage: 117.3+ KB

# %%
total_df['total_score'].unique()
# Out:
# array(['96.1', '96', '95.6', '94.3', '94.2', '91.2', '91.1', '90.6',
#        '89.5', '87.7', '86.9', '86.4', '83.9', '83.4', '82', '81', '79.5',
#        '79.3', '79.2', '78.4', '78', '76.5', '75.9', '75.6', '75.3',
#        '75.1', '75', '73.8', '73.2', '73', '72.9', '71.7', '71', '70.7',
#        '69.9', '69.5', '69.2', '69', '68.6', '67', '66.9', '66.5', '66',
#        '65.9', '65.6', '65.2', '65', '64.9', '64.7', '64.6', '64.2', '64',
#        '63.9', '63', '62.8', '62.7', '62.2', '62.1', '61.6', '61.4',
#        '61.2', '61.1', '60.7', '60.4', '60.3', '59.7', '59.6', '59.5',
#        '59.1', '59', '58.9', '58.3', '58', '57.9', '57.8', '57.7', '57.6',
#        '57.5', '57.3', '57.2', '57.1', '57', '56.9', '56.6', '56.5',
#        '56.4', '56.3', '56.2', '56.1', '56', '55.6', '55.4', '55.3',
#        '55.2', '55.1', '55', '54.8', '54.6', '54.5', '54.4', '54.3',
#        '54.2', '54', '53.4', '53.3', '52.7', '52.6', '52.5', '52.4',
# ...

# %%
total_df['total_score'] = total_df['total_score'].apply(lambda x: float(x))
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1001 entries, 0 to 1602
# Data columns (total 14 columns):
# world_rank                1001 non-null object
# university_name           1001 non-null object
# country                   1001 non-null object
# teaching                  1001 non-null float64
# international             1001 non-null float64
# research                  1001 non-null float64
# citations                 1001 non-null float64
# income                    1001 non-null float64
# total_score               1001 non-null float64
# num_students              984 non-null float64
# student_staff_ratio       984 non-null float64
# international_students    983 non-null float64
# female_male_ratio         1001 non-null object
# year                      1001 non-null int64
# dtypes: float64(9), int64(1), object(4)
# memory usage: 117.3+ KB

# %%
total_df['international_students'].unique()
# Out:
# array(['25%', '27%', '33%', '22%', '34%', '15%', '51%', '20%', '21%',
#        '23%', '19%', '37%', '16%', '28%', '35%', '38%', '46%', '13%',
#        '17%', '10%', '26%', '4%', '11%', '8%', '14%', '30%', '36%', '12%',
#        nan, '54%', '2%', '7%', '18%', '1%', '24%', '9%', '29%', '5%', '6%',
#        '47%', '39%', '40%', '31%', '48%', '32%'], dtype=object)

# %%
total_df['international_students'] = total_df['international_students'].apply(lambda x: str(x).replace('%','0')).apply(lambda x: float(x))
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1001 entries, 0 to 1602
# Data columns (total 14 columns):
# world_rank                1001 non-null object
# university_name           1001 non-null object
# country                   1001 non-null object
# teaching                  1001 non-null float64
# international             1001 non-null float64
# research                  1001 non-null float64
# citations                 1001 non-null float64
# income                    1001 non-null float64
# total_score               1001 non-null float64
# num_students              984 non-null float64
# student_staff_ratio       984 non-null float64
# international_students    983 non-null float64
# female_male_ratio         1001 non-null object
# year                      1001 non-null int64
# dtypes: float64(9), int64(1), object(4)
# memory usage: 117.3+ KB

# %%
total_df['num_students'].unique()
# Out:
# array(['20,152', '2,243', '11,074', '15,596', '7,929', '18,812', '19,919',
#        '36,186', '15,060', '11,751', '38,206', '14,221', '15,128',
#        '21,424', '18,178', '41,786', '66,198', '25,055', '20,376',
#        '11,885', '19,835', '26,607', '44,020', '15,172', '18,334',
#        '26,199', '19,967', '3,055', '22,020', '50,152', '26,518', '27,233',
#        '42,727', '31,592', '31,326', '40,128', '40,148', '12,528', '2,429',
#        '25,774', '11,385', '2,400', '14,604', '7,774', '25,581', nan,
#        '6,333', '9,666', '26,614', '14,290', '12,161', '46,825', '10,410',
#        '35,364', '8,653', '56,959', '22,809', '39,763', '24,789', '42,056',
#        '12,338', '35,691', '11,829', '26,485', '9,259', '51,462', '29,325',
#        '17,906', '17,404', '6,753', '41,868', '23,845', '20,771', '36,534',
#        '7,867', '15,521', '21,394', '21,908', '9,027', '12,001', '34,718',
#        '28,881', '25,674', '15,489', '34,938', '8,747', '28,251', '20,925',
# ...

# %%
total_df['num_students'] = total_df['num_students'].apply(lambda x: str(x).replace(',', '' )).apply(lambda x: float(x))
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1001 entries, 0 to 1602
# Data columns (total 14 columns):
# world_rank                1001 non-null object
# university_name           1001 non-null object
# country                   1001 non-null object
# teaching                  1001 non-null float64
# international             1001 non-null float64
# research                  1001 non-null float64
# citations                 1001 non-null float64
# income                    1001 non-null float64
# total_score               1001 non-null object
# num_students              984 non-null float64
# student_staff_ratio       984 non-null float64
# international_students    983 non-null float64
# female_male_ratio         897 non-null object
# year                      1001 non-null int64
# dtypes: float64(8), int64(1), object(5)
# memory usage: 117.3+ KB

# %%
total_df['female_male_ratio'].unique()
# Out:
# array([nan, '33 : 67', '37 : 63', '42:58:00', '45:55:00', '46:54:00',
#        '50:50:00', '52:48:00', '48:52:00', '31 : 69', '51:49:00',
#        '39 : 61', '53:47:00', '56:44:00', '49:51:00', '0.888888889',
#        '54:46:00', '58:42:00', '47:53:00', '55:45:00', '0.806944444',
#        '70:30:00', '44:56:00', '27 : 73', '32 : 68', '62:38:00',
#        '57:43:00', '61:39:00', '66:34:00', '30 : 70', '0.602083333',
#        '0.847916667', '59:41:00', '25 : 75', '60:40:00', '26 : 74',
#        '67:33:00', '41:59:00', '63:37:00', '35 : 65', '28 : 72', '34 : 66',
#        '43:57:00'], dtype=object)

# %%
total_df['year'].unique()
# Out:
# array([2011, 2012, 2013, 2014, 2015])

# %%
def f_m_r(str):
    D1 = (str[0:2])
    print D1   
    return D1
    


def sale_convert(df):    
    df2 = df.iloc[:,17]
    df3 = df2.apply(sale_convt)
    
    print df3
    
    
sale_convert(df)

# %%
gender_ratio = total_df['female_male_ratio'].apply(lambda x: str(x).split(':'))
[x[0] for x in gender_ratio]

gender_list = []

for x in gender_ratio:
   if x[0] == 'nan':
       gender_list.append('nan')
   elif x[0] < 1:
       gender_list.append(x[0])
   else:
       ratio = float(x[0])/(100 - float(x[0]))
       gender_list.append(ratio)

len(gender_list)
total_df['female_male_ratio'] = gender_list

print total_df.head(3)
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
#
#    teaching  international  research  citations  income  total_score  \
# 0      99.7           72.4      98.7       98.8    34.5         96.1
# 1      97.7           54.6      98.0       99.9    83.7         96.0
# 2      97.8           82.3      91.4       99.9    87.5         95.6
#
#    num_students  student_staff_ratio  international_students  \
# 0       20152.0                  8.9                   250.0
# 1        2243.0                  6.9                   270.0
# 2       11074.0                  9.0                   330.0
#
#   female_male_ratio  year
# 0               nan  2011
# 1          4.95e-07  2011
# 2       5.90806e-07  2011

# %%
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1001 entries, 0 to 1602
# Data columns (total 14 columns):
# world_rank                1001 non-null object
# university_name           1001 non-null object
# country                   1001 non-null object
# teaching                  1001 non-null float64
# international             1001 non-null float64
# research                  1001 non-null float64
# citations                 1001 non-null float64
# income                    1001 non-null float64
# total_score               1001 non-null float64
# num_students              984 non-null float64
# student_staff_ratio       984 non-null float64
# international_students    983 non-null float64
# female_male_ratio         1001 non-null object
# year                      1001 non-null int64
# dtypes: float64(9), int64(1), object(4)
# memory usage: 117.3+ KB

# %%
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1001 entries, 0 to 1602
# Data columns (total 14 columns):
# world_rank                1001 non-null object
# university_name           1001 non-null object
# country                   1001 non-null object
# teaching                  1001 non-null float64
# international             1001 non-null float64
# research                  1001 non-null float64
# citations                 1001 non-null float64
# income                    1001 non-null float64
# total_score               1001 non-null float64
# num_students              984 non-null float64
# student_staff_ratio       984 non-null float64
# international_students    983 non-null float64
# female_male_ratio         1001 non-null object
# year                      1001 non-null int64
# dtypes: float64(9), int64(1), object(4)
# memory usage: 117.3+ KB

# %%
total_df = total_df.dropna(axis = 0)
X = total_df.iloc[:,[3,4,5,6,7,9,10,11]]
y = total_df['total_score’]
sub_total = total_df.iloc[:,3:-2]

for x in X.columns:
   sns.pairplot(data = sub_total,y_vars = 'total_score',x_vars = x)

lm = linear_model.LinearRegression()

model = lm.fit(X,y)

predict = model.predict(X)

print model.score(X,y)
print model.coef_
plt.scatter(predict,y)
print "MSE:", mean_squared_error(y, predict)
# Out:
#   File "<ipython-input-81-30140e353bd3>", line 3
#     y = total_df['total_score’]
#
# ^
# SyntaxError: EOL while scanning string literal

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

lasso = linear_model.Lasso(alpha=1)

lasso_model = lasso.fit(X, y)
X = total_df.iloc[:,[3,4,5,6,7,9,10,11]]
y_true_lasso = y
y_pred_lasso = lasso_model.predict(X)

lasso_r2 =  r2_score(y_true=y_true_lasso, y_pred=y_pred_lasso)

print "The Lasso r^2:",lasso_r2

print "MSE:", mean_squared_error(y, y_pred_lasso)
print lasso.coef_
print "with lasso, international students and student staff ratio got eliminated"
print "the data has a high correlation, the strongest predictors are research, citations, and teaching"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-a280914cbf6a> in <module>()
#       4 lasso = linear_model.Lasso(alpha=1)
#       5
# ----> 6 lasso_model = lasso.fit(X, y)
#       7 X = total_df.iloc[:,[3,4,5,6,7,9,10,11]]
#       8 y_true_lasso = y
#
# NameError: name 'X' is not defined
